# %% [markdown]
# # Data Cleaning Task of Income Classification

# %% [markdown]
# ## 1. Load the data

# %%
#we have used census dataset for income classification

# %%
#import all the libraries used in our dataset
import pandas as pd
import numpy as np

# %%
#load csv file into notebook
df=pd.read_csv("../Dataset/Income_Classification.csv")
#first five rows from csv
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# ...

# %%
#last five rows from dataset
df.tail()
# Out:
#        age      workclass   fnlwgt    education   education-num  \
# 32556   27        Private   257302   Assoc-acdm              12
# 32557   40        Private   154374      HS-grad               9
# 32558   58        Private   151910      HS-grad               9
# 32559   22        Private   201490      HS-grad               9
# 32560   52   Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation  relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support          Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct       Husband   White     Male
# 32558              Widowed        Adm-clerical     Unmarried   White   Female
# 32559        Never-married        Adm-clerical     Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial          Wife   White   Female
#
#         capital-gain   capital-loss   hours-per-week  native-country  income
# ...

# %% [markdown]
# ## 2. Describe the data

# %%
# it is used to describe statistical analysis of data
df.describe()
# Out:
#                 age        fnlwgt   education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %%
# this gives the information about every column of our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age                32561 non-null int64
#  workclass         32561 non-null object
#  fnlwgt            32561 non-null int64
#  education         32561 non-null object
#  education-num     32561 non-null int64
#  marital-status    32561 non-null object
#  occupation        32561 non-null object
#  relationship      32561 non-null object
#  race              32561 non-null object
#  sex               32561 non-null object
#  capital-gain      32561 non-null int64
#  capital-loss      32561 non-null int64
#  hours-per-week    32561 non-null int64
#  native-country    32561 non-null object
#  income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# check whether the our dataset have null values or not
df.isnull().sum()
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  income            0
# dtype: int64

# %%
# count unique values from each column
df.nunique(axis=0)
# Out:
# age                   73
#  workclass             9
#  fnlwgt            21648
#  education            16
#  education-num        16
#  marital-status        7
#  occupation           15
#  relationship          6
#  race                  5
#  sex                   2
#  capital-gain        119
#  capital-loss         92
#  hours-per-week       94
#  native-country       42
#  income                2
# dtype: int64

# %%
# return all the columns in dataset
Column=list(df.columns)

# %%
Column
# Out:
# ['age',
#  ' workclass',
#  ' fnlwgt',
#  ' education',
#  ' education-num',
#  ' marital-status',
#  ' occupation',
#  ' relationship',
#  ' race',
#  ' sex',
#  ' capital-gain',
#  ' capital-loss',
#  ' hours-per-week',
#  ' native-country',
#  ' income']

# %%
for x in Column:
    print(x,df[x].unique())
    print()
# Out:
# age [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
#  workclass [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
#  fnlwgt [ 77516  83311 215646 ...  34066  84661 257302]
#
#  education [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
#  education-num [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
#  marital-status [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
#  occupation [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
# ...

# %% [markdown]
# ## 3. Remove Insignificant Column

# %%
clean_df=df.drop(df.columns[[2,3,5,7,8]],axis=1)

# %%
clean_df.head()
# Out:
#    age          workclass   education-num          occupation      sex  \
# 0   39          State-gov              13        Adm-clerical     Male
# 1   50   Self-emp-not-inc              13     Exec-managerial     Male
# 2   38            Private               9   Handlers-cleaners     Male
# 3   53            Private               7   Handlers-cleaners     Male
# 4   28            Private              13      Prof-specialty   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
df.drop(df.columns[[2,3,5,7,8]],axis=1,inplace=True)
df.head()
# Out:
#    age          workclass   education-num          occupation      sex  \
# 0   39          State-gov              13        Adm-clerical     Male
# 1   50   Self-emp-not-inc              13     Exec-managerial     Male
# 2   38            Private               9   Handlers-cleaners     Male
# 3   53            Private               7   Handlers-cleaners     Male
# 4   28            Private              13      Prof-specialty   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %% [markdown]
# ## 4. Check Missing value for each columns

# %%
Clean_col=list(clean_df.columns)

# %%
Clean_col
# Out:
# ['age',
#  ' workclass',
#  ' education-num',
#  ' occupation',
#  ' sex',
#  ' capital-gain',
#  ' capital-loss',
#  ' hours-per-week',
#  ' native-country',
#  ' income']

# %%
for x in Clean_col:
    print(x,df[x].value_counts())
# Out:
# age 36    898
# 31    888
# 34    886
# 23    877
# 35    876
# 33    875
# 28    867
# 30    861
# 37    858
# 25    841
# 27    835
# 32    828
# 38    827
# 39    816
# 29    813
# 41    808
# 24    798
# 40    794
# 26    785
# 42    780
# 43    770
# 22    765
# 20    753
# 46    737
# 45    734
# 44    724
# 21    720
# 19    712
# 47    708
# 50    602
#      ...
# 60    312
# 61    300
# 62    258
# 63    230
# 64    208
# 65    178
# 67    151
# 66    150
# 68    120
# 69    108
# 70     89
# 71     72
# 72     67
# 73     64
# 74     51
# 76     46
# 75     45
# 90     43
# 77     29
# 78     23
# 80     22
# 79     22
# 81     20
# 82     12
# 84     10
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64
#  workclass  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
# ...

# %%
df.head(15)
# Out:
#     age          workclass   education-num          occupation      sex  \
# 0    39          State-gov              13        Adm-clerical     Male
# 1    50   Self-emp-not-inc              13     Exec-managerial     Male
# 2    38            Private               9   Handlers-cleaners     Male
# 3    53            Private               7   Handlers-cleaners     Male
# 4    28            Private              13      Prof-specialty   Female
# 5    37            Private              14     Exec-managerial   Female
# 6    49            Private               5       Other-service   Female
# 7    52   Self-emp-not-inc               9     Exec-managerial     Male
# 8    31            Private              14      Prof-specialty   Female
# 9    42            Private              13     Exec-managerial     Male
# 10   37            Private              10     Exec-managerial     Male
# 11   30          State-gov              13      Prof-specialty     Male
# ...

# %%
df.replace('?',np.nan,inplace=True)

# %%
df.head(15)
# Out:
#     age          workclass   education-num          occupation      sex  \
# 0    39          State-gov              13        Adm-clerical     Male
# 1    50   Self-emp-not-inc              13     Exec-managerial     Male
# 2    38            Private               9   Handlers-cleaners     Male
# 3    53            Private               7   Handlers-cleaners     Male
# 4    28            Private              13      Prof-specialty   Female
# 5    37            Private              14     Exec-managerial   Female
# 6    49            Private               5       Other-service   Female
# 7    52   Self-emp-not-inc               9     Exec-managerial     Male
# 8    31            Private              14      Prof-specialty   Female
# 9    42            Private              13     Exec-managerial     Male
# 10   37            Private              10     Exec-managerial     Male
# 11   30          State-gov              13      Prof-specialty     Male
# ...
