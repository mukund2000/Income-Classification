# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from matplotlib import cm
from sklearn.metrics import silhouette_samples
from sklearn.metrics import silhouette_score
from sklearn.metrics import accuracy_score

from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

from sklearn.model_selection import GridSearchCV


#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('../Assignment-3/adult_data_formatted.csv')
df.head()
# Out:
#    Unnamed: 0  age  workclass         occupation gender  capital-gain  \
# 0           0   25    Private  Machine-op-inspct   Male             0
# 1           1   38    Private    Farming-fishing   Male             0
# 2           2   28  Local-gov    Protective-serv   Male             0
# 3           3   44    Private  Machine-op-inspct   Male          7688
# 4           5   34    Private      Other-service   Male             0
#
#    capital-loss  hours-per-week native-country  income  education-num
# 0             0              40  United-States       0              7
# 1             0              50  United-States       0              9
# 2             0              40  United-States       1             12
# 3             0              40  United-States       1             10
# 4             0              30  United-States       0              6

# %%
df.drop(df.columns[[0]],axis=1,inplace=True)

# %%
df.head()
# Out:
#    age  workclass         occupation gender  capital-gain  capital-loss  \
# 0   25    Private  Machine-op-inspct   Male             0             0
# 1   38    Private    Farming-fishing   Male             0             0
# 2   28  Local-gov    Protective-serv   Male             0             0
# 3   44    Private  Machine-op-inspct   Male          7688             0
# 4   34    Private      Other-service   Male             0             0
#
#    hours-per-week native-country  income  education-num
# 0              40  United-States       0              7
# 1              50  United-States       0              9
# 2              40  United-States       1             12
# 3              40  United-States       1             10
# 4              30  United-States       0              6

# %%
df = df.apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    age  workclass  occupation  gender  capital-gain  capital-loss  \
# 0    8          2           6       1             0             0
# 1   21          2           4       1             0             0
# 2   11          1          10       1             0             0
# 3   27          2           6       1            96             0
# 4   17          2           7       1             0             0
#
#    hours-per-week  native-country  income  education-num
# 0              39              38       0              6
# 1              49              38       0              8
# 2              39              38       1             11
# 3              39              38       1              9
# 4              29              38       0              5

# %%
columns=df.columns
X=df[columns]
y=df['income']
print(X.shape,y.shape)
# Out:
# (45222, 10) (45222,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train
# Out:
#        age  workclass  occupation  gender  capital-gain  capital-loss  \
# 9168     4          2           5       1             0             0
# 43815   26          2           3       1             0            55
# 43193    4          2           0       0             0             0
# 15087   32          2           2       1             0             0
# 27545   24          2           2       1             0             0
# 15145   11          2           6       0             0             0
# 3773    33          2          11       1             0             0
# 26303   24          2           0       1             0             0
# 2889    17          2          11       0             0             0
# 30657   15          2           2       1           106             0
# 7813    14          2           0       0             0             0
# 20981    2          2          11       0             0             0
# 20460   26          3           2       1             0             0
# 28029    4          2           7       0             0             0
# 2674     5          2           0       0             0             0
# 39408   23          4           2       1             0             0
# 42655   37          4           2       1             0             0
# 5540     7          2           2       1             0             0
# 8999    15          1          10       0             0             0
# 23949   36          2           0       0            28             0
# 4430    18          3           3       1             0             0
# 40134   15          4           3       1             0             0
# 29984    7          0           1       1             0             0
# 765     33          2           3       1             0             0
# 29948   40          5           2       1             0             0
# 6942    13          2           3       1             0             0
# 36906   35          2           0       0             0             0
# 29802   41          2           0       1             0            49
# 8980    50          3           9       1           113             0
# 16479   45          2           9       1             0            30
# ...    ...        ...         ...     ...           ...           ...
# 27859   36          2           2       1             0             0
# 40390   29          2          11       1             0             0
# 25902   24          2           9       0             0             0
# 42309    7          2           2       1            99             0
# 16639   14          2           0       0             0             0
# 21372   26          2           2       1             0             0
# 20026   11          2          13       1             0            40
# 15905   64          4           3       1             0             0
# 8170    14          1           9       0             0             0
# 29547   42          4           4       1             0             0
# 21418   31          2           3       1             0             0
# 20084    2          4           0       0             0             0
# 41084   48          2           7       0             0             0
# 6548    33          2           4       1             0             0
# 32031   26          2           2       1             0             0
# 11071   29          0          12       0             0             0
# 5167    20          1           3       1             0             0
# 35541   31          2           0       0             0             0
# 43595   16          2           7       0             0             0
# 33201   27          2          11       0             0             0
# 44295   18          2           4       1             0             0
# 14696    6          2          11       0             0            41
# 33867    5          2           0       0             0             0
# 18898    8          2           2       1             0             0
# 31019   24          1           9       1             0            54
# 44566   24          2          11       0             0             0
# 30280   30          2           0       1             0             0
# 6637    34          2          11       0             0             0
# 35343   17          2           0       0             0             0
# 23720   25          2          11       1             0             0
#
#        hours-per-week  native-country  income  education-num
# 9168               39              38       0              6
# 43815              49              38       1             12
# 43193              39              38       0              8
# 15087              39              38       0              8
# 27545              44              38       0              9
# 15145              24              38       0              9
# 3773               59              38       1              8
# 26303              39              38       0              8
# 2889               34              38       0              8
# 30657              59              38       1              6
# 7813               39              38       0              8
# 20981              24              38       0              9
# 20460              39              38       0              8
# 28029              39              38       0             10
# 2674               36              38       0             11
# 39408              14              38       0              8
# 42655              49              38       0             12
# 5540               44              38       0              9
# 8999               49              38       0             10
# 23949              39              38       0             10
# 4430               49              38       0              9
# 40134              44              38       0              5
# 29984              39              38       0             12
# 765                54              38       1             13
# 29948              39              38       0              8
# 6942               39              38       0              8
# 36906              39              38       0              9
# 29802              39              38       0             11
# 8980               59              21       1             13
# 16479              69              38       0             14
# ...               ...             ...     ...            ...
# 27859              39              38       0              8
# 40390              49              10       1             12
# 25902              39              38       0             12
# 42309              39              38       1             11
# 16639              39              38       0              8
# 21372              39              38       1              9
# 20026              39              38       0              8
# 15905              29              38       0              8
# 8170               44              38       0             13
# 29547              29              38       0             14
# 21418              44              38       1             12
# 20084              39              38       0              5
# 41084              19              22       0              8
# 6548               39              25       0              1
# 32031              39              38       0              8
# 11071              39              38       0             10
# 5167               39              38       1             13
# 35541              39              38       0              9
# 43595              24              38       0              9
# 33201              34              38       0              9
# 44295              34              38       0              8
# 14696              49              38       0             12
# 33867              15              38       0              9
# 18898              49              38       0              6
# 31019              39              38       0             13
# 44566              47              38       0              9
# 30280              39              38       0             12
# 6637               30              38       0              8
# 35343              39              38       0             12
# 23720              39              38       0              8
#
# [36177 rows x 10 columns]

# %%
# Logistic Regression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
#y_pred = logreg.predict(X_test)
score_logreg = logreg.score(X_test,y_test)
print('The accuracy of the Logistic Regression is', score_logreg)
# Out:
# C:\Users\Mukund Rastogi\anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# The accuracy of the Logistic Regression is 1.0

# %%
print(logreg.intercept_,logreg.coef_)
# Out:
# [-3.26049875] [[ 2.24275087e-03 -3.79996561e-01 -3.57107922e-02  2.37588916e-01
#    1.44526627e-02  1.35682995e-02 -1.87944682e-02 -7.38578491e-02
#    1.41649335e+01 -1.60864894e-02]]

# %%
y_pred=logreg.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
cfm=confusion_matrix(y_test,y_pred)
sns.heatmap(cfm, annot=True)
plt.xlabel('Predicted classes')
plt.ylabel('Actual classes')
# Out:
# Text(33.0, 0.5, 'Actual classes')

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
# y_pred = gaussian.predict(X_test)
score_gaussian = gaussian.score(X_test,y_test)
print('The accuracy of Gaussian Naive Bayes is', score_gaussian)

# %%
cross_val_model = LogisticRegression(random_state=0)
scores = cross_val_score(cross_val_model, X_train, 
         y_train, cv=5)
print(np.mean(scores))
